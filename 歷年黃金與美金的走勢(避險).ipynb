# %%
# %pip install pandas_datareader

import pandas as pd
import pandas_datareader as pdr
import matplotlib.pyplot as plt
import datetime
# Out:
# Requirement already satisfied: pandas_datareader in c:\users\user\anaconda3\lib\site-packages (0.9.0)
# Requirement already satisfied: pandas>=0.23 in c:\users\user\anaconda3\lib\site-packages (from pandas_datareader) (0.25.1)
# Requirement already satisfied: requests>=2.19.0 in c:\users\user\anaconda3\lib\site-packages (from pandas_datareader) (2.22.0)
# Requirement already satisfied: lxml in c:\users\user\anaconda3\lib\site-packages (from pandas_datareader) (4.4.1)
# Requirement already satisfied: numpy>=1.13.3 in c:\users\user\anaconda3\lib\site-packages (from pandas>=0.23->pandas_datareader) (1.16.5)
# Requirement already satisfied: pytz>=2017.2 in c:\users\user\anaconda3\lib\site-packages (from pandas>=0.23->pandas_datareader) (2019.3)
# Requirement already satisfied: python-dateutil>=2.6.1 in c:\users\user\anaconda3\lib\site-packages (from pandas>=0.23->pandas_datareader) (2.8.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\anaconda3\lib\site-packages (from requests>=2.19.0->pandas_datareader) (2019.9.11)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\user\anaconda3\lib\site-packages (from requests>=2.19.0->pandas_datareader) (1.24.2)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\user\anaconda3\lib\site-packages (from requests>=2.19.0->pandas_datareader) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\user\anaconda3\lib\site-packages (from requests>=2.19.0->pandas_datareader) (2.8)
# Requirement already satisfied: six>=1.5 in c:\users\user\anaconda3\lib\site-packages (from python-dateutil>=2.6.1->pandas>=0.23->pandas_datareader) (1.12.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
stock_number = ['DJIA','^GSPC']
start = datetime.datetime(2000,1,1)
end   = datetime.datetime(2020,7,1)
df_stock = pdr.DataReader(stock_number, 'yahoo', start, end)

# %%
USD_number = ['DX-Y.NYB']
start = datetime.datetime(2000,1,1)
end   = datetime.datetime(2020,7,1)
df_USD = pdr.DataReader(USD_number, 'yahoo', start, end)

# %%
gold = ['GOLDAMGBD228NLBM'] # the Gold Fixing Price 10:30 AM (London time) in London Bullion Market, in US Dollars
start = datetime.datetime(2000,1,1)
end   = datetime.datetime(2020,7,1)
df_gold = pdr.DataReader(gold, 'fred', start, end) # Federal Reserve Economic Data (FRED) portal

# %%
df_gold.head()
# Out:
#             GOLDAMGBD228NLBM
# DATE
# 2000-01-03               NaN
# 2000-01-04            282.05
# 2000-01-05            282.10
# 2000-01-06            280.35
# 2000-01-07            282.00

# %%
plt.plot(df_gold)
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\converter.py:103: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %%
df_gold.rolling(20).mean()
# Out:
#             GOLDAMGBD228NLBM
# DATE
# 2000-01-03               NaN
# 2000-01-04               NaN
# 2000-01-05               NaN
# 2000-01-06               NaN
# 2000-01-07               NaN
# ...                      ...
# 2020-06-25         1728.6375
# 2020-06-26         1730.4600
# 2020-06-29         1732.1600
# 2020-06-30         1733.6825
# 2020-07-01         1737.1725
#
# [5348 rows x 1 columns]

# %%
fig, ax1 = plt.subplots(figsize=(10,8))
curve1 = ax1.plot(df_USD.Close.rolling(20).mean(),'-r')
ax1.set_xlabel('time (year)')
ax1.set_ylabel('US Dollar Index',fontsize=12)
ax1.legend()
ax2 = ax1.twinx()
curve2 = ax2.plot(df_gold.rolling(20).mean(),'-b')
ax2.set_ylabel('Gold',fontsize=12)
ax2.legend(['gold'],loc=1)
ax1.grid()
# Out:
# No handles with labels found to put in legend.

# %%
USD_number = ['DX-Y.NYB']
start = datetime.datetime(2000,1,1)
end   = datetime.datetime(2008,7,1)
df_USD = pdr.DataReader(USD_number, 'yahoo', start, end)

gold = ['GOLDAMGBD228NLBM'] # the Gold Fixing Price 10:30 AM (London time) in London Bullion Market, in US Dollars
start = datetime.datetime(2000,1,1)
end   = datetime.datetime(2008,7,1)
df_gold = pdr.DataReader(gold, 'fred', start, end) # Federal Reserve Economic Data (FRED) portal

fig, ax1 = plt.subplots(figsize=(10,8))
curve1 = ax1.plot(df_USD.Close.rolling(20).mean(),'-r')
ax1.set_xlabel('time (year)')
ax1.set_ylabel('US Dollar Index',fontsize=12)
ax1.legend()
ax2 = ax1.twinx()
curve2 = ax2.plot(df_gold.rolling(20).mean(),'-b')
ax2.set_ylabel('Gold',fontsize=12)
ax2.legend(['gold'],loc=1)
ax1.grid()
# Out:
# No handles with labels found to put in legend.

# %%
DJvsUSD = pd.concat([df_USD,df_gold], axis=1, sort=False).dropna()

# %%
DJvsUSD.GOLDAMGBD228NLBM.corr()

# %%
USD_number = ['DX-Y.NYB']
start = datetime.datetime(2008,1,1)
end   = datetime.datetime(2020,7,1)
df_USD = pdr.DataReader(USD_number, 'yahoo', start, end)

gold = ['GOLDAMGBD228NLBM'] # the Gold Fixing Price 10:30 AM (London time) in London Bullion Market, in US Dollars
start = datetime.datetime(2008,1,1)
end   = datetime.datetime(2020,7,1)
df_gold = pdr.DataReader(gold, 'fred', start, end) # Federal Reserve Economic Data (FRED) portal

fig, ax1 = plt.subplots(figsize=(10,8))
curve1 = ax1.plot(df_USD.Close.rolling(20).mean(),'-r')
ax1.set_xlabel('time (year)')
ax1.set_ylabel('US Dollar Index',fontsize=12)
ax1.legend()
ax2 = ax1.twinx()
curve2 = ax2.plot(df_gold.rolling(20).mean(),'-b')
ax2.set_ylabel('Gold',fontsize=12)
ax2.legend(['gold'],loc=1)
ax1.grid()
# Out:
# No handles with labels found to put in legend.

# %%
DJvsGOLD = pd.concat([df_USD, df_gold], axis=1, sort=False).dropna()
